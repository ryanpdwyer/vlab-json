# %%
data = '''{
    "solutions": {
      "FILESYSTEM": {
        "DIRECTORY": [
          {
            "name": "stockroom",
            "SOLUTION": [
              {
                "name": "Distilled H<sub>2</sub>O",
                "description": "Distilled Water",
                "volume": "3.0",
                "vessel": "3LCarboy",
                "species": [
                  {
                    "id": "0",
                  }
                ]
              },
             {
                      "name": "3M NH<sub>3</sub>",
                      "description": "3 Molar Ammonia",
                      "volume": "0.1",
                      "species": [
                        {
                          "id": "0"
                        },
                        {
                          "id": "33",
                          "amount": "0.3"
                        }
                      ]
                    },
              {
                      "name": "1M NaOH",
                      "description": "1M Sodium Hydroxide",
                      "volume": "0.1",
                      "species": [
                        {
                          "id": "0"
                        },
                        {
                          "id": "8",
                          "amount": "0.01"
                        },
                        {
                          "id": "2",
                          "amount": "0.01"
                        }
                      ]
                    },
              
              
              
              
              
              {
                  "name": "Cu<sup>2+</sup> solution",
                  "description": "Copper(II) Sulfate Solution",
                  "volume": "0.1",
                  "species": [
                    {
                      "id": "0"
                    },
                    {
                      "id": "300",
                      "amount": ".01"
                    },
                    {
                      "id": "30",
                      "amount": ".01"
                    }
                  ]
                },
  
              
             {
                      "name": "3M H<sub>2</sub>SO<sub>4</sub>",
                      "description": "3 Molar Sulfuric Acid",
                      "volume": "0.1",
                      "species": [
                        {
                          "id": "0"
                        },
                        {
                          "id": "29",
                          "amount": "0.3"
                        },
                        {
                          "id": "1",
                          "amount": "0.3"
                        }
                      ]
                    },
              
              
              
            ]
          }
        ]
      }
    },
    
    
    
    
    
    
    
    
    
    
    
    
    
    
   "species": {
      "SPECIES_LIST": {
        "SPECIES": [
          {
            "entropy": "69.91",
            "name": "H<sub>2</sub>O",
            "state": "l",
            "enthalpy": "-285.83",
            "density": "1.000",
            "specificHeat": "1.000",
            "molecularWeight": "18.01534",
            "id": "0"
          },
          
          
          
          
          
          
          
          
          
          
          
          {
            "entropy": "0.0",
            "name": "H<sup>+</sup>",
            "enthalpy": "0.0",
            "id": "1"
          },
          
          
          
          
          
          
          
          {
            "entropy": "-10.75",
            "name": "OH<sup>-</sup>",
            "enthalpy": "-229.99",
            "id": "2"
          },
          
          
        
          
          
   {
              "id": "6",
              "name": "NH<sub>4</sub><sup>+</sup>",
              "simpleName": "NH4^+",
              "state": "aq",
              "enthalpy": -133.26,
              "entropy": 111.17
            },
          {
            "id": "8",
            "name": "Na<sup>+</sup>",
            "enthalpy": "-240.1",
            "molecularWeight": "22.99",
            "entropy": "59.0",
            "density": "0.971"
          },
          {
              "id": "9",
              "name": "Cl<sup>-</sup>",
              "enthalpy": "-167.16",
              "entropy": "56.5",
              "molecularWeight": "35.453"
            },
          {
              "id": "29",
              "name": "HSO<sub>4</sub><sup>-</sup>",
              "enthalpy": "-885.75",
              "entropy": "126.86",
              "molecularWeight": "97.078"
            },
            {
              "id": "30",
              "name": "SO<sub>4</sub><sup>2-</sup>",
              "enthalpy": "-907.51",
              "entropy": "17.15",
              "molecularWeight": "96.07"
            },
          {
              "id": "33",
              "name": "NH<sub>3</sub>",
              "enthalpy": "-80.29",
              "entropy": "111.42",
              "molecularWeight": "17.034"
            },
          {
              "id": "300",
              "name": "Cu<sup>+2</sup>",
              "enthalpy": "64.77",
              "entropy": "-99.6",
              "hue": "160",
              "saturation": "88",
              "value": "100",
              "colorConcentration": ".08"
            },
  
            {
              "id": "302",
              "name": "CuCl<sub>2</sub>",
              "enthalpy": "-264.9",
              "entropy": "100",
              "state": "s",
              "molecularWeight": "99",
              "hue": "130",
              "saturation": "88",
              "value": "100",
              "colorConcentration": ".3"
            },
  
          {
              "id": "304",
              "name": "Cu(NH<sub>3</sub>)<sub>4</sub>",
              "enthalpy": "-348.27",
              "entropy": "287.18",
              "molecularWeight": "131.6670",
              "hue": "242",
              "saturation": "86",
              "value": "70",
              "colorConcentration": ".017" 
            },
  
          
          
        ]
      }
   },
    "spectra": {
      "SPECTRA_LIST": {
        "SPECIES": []
      }
    },
    "reactions": {
      "REACTIONS": {
        "REACTION": [
          {
            "SPECIES_REF": [
              {
                "id": "0",
                "coefficient": "-1"
              },
              {
                "id": "1",
                "coefficient": "1"
              },
              {
                "id": "2",
                "coefficient": "1"
              }
            ]
          },
          
          
          
          {
              "SPECIES_REF": [
                {
                  "id": "9",
                  "coefficient": "-2"
                },
                {
                  "id": "300",
                  "coefficient": "-1"
                },
                {
                  "id": "302",
                  "coefficient": "1"
                }
              ]
            },
  
          
          {
              "SPECIES_REF": [
                {
                  "id": "6",
                  "coefficient": "-1"
                },
                {
                  "id": "1",
                  "coefficient": "1"
                },
                {
                  "id": "33",
                  "coefficient": "1"
                }
              ]
            },
  
          
          {
  "SPECIES_REF": [
                {
                  "id": "300",
                  "coefficient": "-1"
                },
                {
                  "id": "33",
                  "coefficient": "-4"
                },
                {
                  "id": "304",
                  "coefficient": "1"
                },
  
              ]
            },
  
          {
              "SPECIES_REF": [
                {
                  "id": "30",
                  "coefficient": "1"
                },
                {
                  "id": "1",
                  "coefficient": "1"
                },
                {
                  "id": "29",
                  "coefficient": "-1"
                }
              ]
            },
          
          
        
        ]
      }
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
   
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    },
   "assignment": {
      "assignmentText": "text"
    },
    "configuration": {
      "title": "Copper (II) Equilibrium and LeChatlier's Principle ",
      "solutionViewers": [
        {
          "id": "solutionProperties",
          "displayDefault": true,
          "args": {
            "honorSignificantFigures": false
          }
        },
        {
          "id": "aqueous",
          "displayDefault": true,
          "args": {
            "unitsToggleEnabled": true
          }
        },
        {
          "id": "solid",
          "displayDefault": true,
          "args": {
            "unitsToggleEnabled": true
          }
        },
        {
          "id": "spectrometer",
          "displayDefault": false
        },
        {
          "id": "particleView",
          "displayDefault": false
        },
        {
          "id": "thermometer",
          "displayDefault": true
        },
        {
          "id": "pH",
          "displayDefault": true
        },
        {
          "id": "vesselTrackingControl",
          "displayDefault": false
        }
      ],
      "transfer": [
        "precise",
        "significantFigures",
        "realistic"
      ]
    }
    }
  '''

# %%
# Use a json library that is less strict about the format
import json5 as json
data_dict = json.loads(data)

# HTML print the reactions
# Okay for it to only work in IPython notebook
from IPython.display import HTML
import pandas as pd

# %%
# Calculate Delta H, Delta S, and Delta G for each reaction

# Get the reactions
reactions = data_dict['reactions']['REACTIONS']['REACTION']
# Get the species
species = data_dict['species']['SPECIES_LIST']['SPECIES']
# Turn the list of species with IDs to a dictionary with id as the key
species_dict = {s['id']: s for s in species}

def string_reaction_side(side):
    species_strings = []
    for species in side:
        if species['coeff'] == 1:
            species_strings.append(species['name'])
        else:
            species_strings.append(str(species['coeff']) + species['name'])
    return ' + '.join(species_strings)

# Calculate the delta H, delta S, and delta G for each reaction
for reaction in reactions:
    # Get the species in the reaction
    species_in_reaction = reaction['SPECIES_REF']
    # Calculate the delta H
    delta_H = sum([float(species_dict[s['id']]['enthalpy']) * float(s['coefficient']) for s in species_in_reaction])
    # Calculate the delta S
    delta_S = sum([float(species_dict[s['id']]['entropy']) * float(s['coefficient']) for s in species_in_reaction])
    # Calculate the delta G
    delta_G = delta_H - 298.15 * delta_S / 1000
    # Add the delta H, delta S, and delta G to the reaction
    reaction['delta_H'] = delta_H
    reaction['delta_S'] = delta_S
    reaction['delta_G'] = delta_G
    reaction['log_K'] = -delta_G / (2.303 * 298.15 * 0.0083145)
    # Write the reaction to a string
    reactants = []
    products = []
    for species_ in species_in_reaction:
        # Convert to an int if the coefficient is an integer
        if float(species_['coefficient']) == int(species_['coefficient']):
            coeff = int(species_['coefficient'])
        else:
            coeff = float(species_['coefficient'])
        if float(species_['coefficient']) < 0:
            reactants.append(dict(name=species_dict[species_['id']]['name'], coeff=-coeff))
        else:
            products.append(dict(name=species_dict[species_['id']]['name'], coeff=coeff))

    reaction_string = string_reaction_side(reactants) + ' -> ' + string_reaction_side(products)
    reaction['name'] = reaction_string
    reaction['html'] = HTML(reaction_string)

reactions_df = pd.DataFrame(reactions)

# %%
# Export species, reactions to Excel - one sheet for each
import pandas as pd
import numpy as np
import os
import openpyxl
from openpyxl.utils.dataframe import dataframe_to_rows

# Create a Pandas dataframe for the species
species_df0 = pd.DataFrame(species)
# Convert these columns to float: enthalpy	density	specificHeat	molecularWeight entropy
species_df = species_df0.astype({'enthalpy': 'float', 'density': 'float', 'specificHeat': 'float', 'molecularWeight': 'float', 'entropy': 'float', 'id': 'int'}, errors='ignore')

if 'simpleName' not in species_df.columns:
    species_df['simpleName'] = ""

species_df.replace(dict(unknown={'true': True, 'false': False}), inplace=True)

species_df = species_df.loc[:, ['id', 'name', 'state', 'simpleName', 'enthalpy', 'entropy', 'molecularWeight', 'density', 'colorConcentration', 'hue', 'saturation', 'value', 'unknown']]

species_df.fillna({'state': 'aq', 'unknown': False}, inplace=True)

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('data.xlsx', engine='xlsxwriter')

# Write each dataframe to a different worksheet.
species_df.to_excel(writer, sheet_name='Species', index=False)
reactions_df.to_excel(writer, sheet_name='Reactions', index=False)

writer.save()
writer.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/9j/cpbbgchx5r5_gsh1n6yplhpr0000gn/T/ipykernel_42885/2831200947.py in <module>
#      16 species_df.replace(dict(unknown={'true': True, 'false': False}), inplace=True)
#      17
# ---> 18 species_df = species_df.loc[:, ['id', 'name', 'state', 'simpleName', 'enthalpy', 'entropy', 'molecularWeight', 'density', 'colorConcentration', 'hue', 'saturation', 'value', 'unknown']]
#      19
#      20 species_df.fillna({'state': 'aq', 'unknown': False}, inplace=True)
#
# ~/opt/miniconda3/envs/py310/lib/python3.10/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/opt/miniconda3/envs/py310/lib/python3.10/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ~/opt/miniconda3/envs/py310/lib/python3.10/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     804                 continue
#     805
# --> 806             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     807             # We should never have retval.ndim < self.ndim, as that should
#     808             #  be handled by the _getitem_lowerdim call above.
#
# ~/opt/miniconda3/envs/py310/lib/python3.10/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ~/opt/miniconda3/envs/py310/lib/python3.10/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/opt/miniconda3/envs/py310/lib/python3.10/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/opt/miniconda3/envs/py310/lib/python3.10/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['unknown'] not in index"

# %%
reactions_df
# Out:
#                                          SPECIES_REF  delta_H  delta_S  \
# 0  [{'id': '0', 'coefficient': '-1'}, {'id': '1',...    55.84   -80.66
# 1  [{'id': '9', 'coefficient': '-2'}, {'id': '300...     4.65    86.60
# 2  [{'id': '6', 'coefficient': '-1'}, {'id': '1',...    52.97     0.25
# 3  [{'id': '300', 'coefficient': '-1'}, {'id': '3...  -303.88   -58.90
# 4  [{'id': '30', 'coefficient': '1'}, {'id': '1',...   -21.76  -109.71
#
#       delta_G      log_K                                               name  \
# 0   79.888779 -13.993324   H<sub>2</sub>O -> H<sup>+</sup> + OH<sup>-</sup>
# 1  -21.169790   3.708102  2Cl<sup>-</sup> + Cu<sup>+2</sup> -> CuCl<sub>...
# 2   52.895462  -9.265173  NH<sub>4</sub><sup>+</sup> -> H<sup>+</sup> + ...
# 3 -286.318965  50.151650  Cu<sup>+2</sup> + 4NH<sub>3</sub> -> Cu(NH<sub...
# 4   10.950037  -1.918009  HSO<sub>4</sub><sup>-</sup> -> SO<sub>4</sub><...
#
#                                  html
# 0  <IPython.core.display.HTML object>
# 1  <IPython.core.display.HTML object>
# 2  <IPython.core.display.HTML object>
# 3  <IPython.core.display.HTML object>
# 4  <IPython.core.display.HTML object>

# %%
species_df
# Out:
#     entropy                            name state  enthalpy  density  \
# 0     69.91                  H<sub>2</sub>O     l   -285.83    1.000
# 1      0.00                   H<sup>+</sup>   NaN      0.00      NaN
# 2    -10.75                  OH<sup>-</sup>   NaN   -229.99      NaN
# 3    111.17      NH<sub>4</sub><sup>+</sup>    aq   -133.26      NaN
# 4     59.00                  Na<sup>+</sup>   NaN   -240.10    0.971
# 5     56.50                  Cl<sup>-</sup>   NaN   -167.16      NaN
# 6    126.86     HSO<sub>4</sub><sup>-</sup>   NaN   -885.75      NaN
# 7     17.15     SO<sub>4</sub><sup>2-</sup>   NaN   -907.51      NaN
# 8    111.42                  NH<sub>3</sub>   NaN    -80.29      NaN
# 9    -99.60                 Cu<sup>+2</sup>   NaN     64.77      NaN
# 10   100.00                CuCl<sub>2</sub>     s   -264.90      NaN
# 11   287.18  Cu(NH<sub>3</sub>)<sub>4</sub>   NaN   -560.27      NaN
#
#     specificHeat  molecularWeight   id simpleName  hue saturation value  \
# 0            1.0         18.01534    0        NaN  NaN        NaN   NaN
# 1            NaN              NaN    1        NaN  NaN        NaN   NaN
# 2            NaN              NaN    2        NaN  NaN        NaN   NaN
# 3            NaN              NaN    6      NH4^+  NaN        NaN   NaN
# 4            NaN         22.99000    8        NaN  NaN        NaN   NaN
# 5            NaN         35.45300    9        NaN  NaN        NaN   NaN
# 6            NaN         97.07800   29        NaN  NaN        NaN   NaN
# 7            NaN         96.07000   30        NaN  NaN        NaN   NaN
# 8            NaN         17.03400   33        NaN  NaN        NaN   NaN
# 9            NaN              NaN  300        NaN  160         88   100
# 10           NaN         99.00000  302        NaN  130         88   100
# 11           NaN        131.66700  304        NaN  242         86    70
#
#    colorConcentration
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 .08
# 10                 .3
# 11               .017

# %%
# !open data.xlsx

# %%
# HTML print the reactions
# Okay for it to only work in IPython notebook
from IPython.display import HTML

for r in reactions:
    HTML(r['name'])

# %%
# Display the HTML
HTML('<br>'.join([r['name'] for r in reactions]))
# Out:
# H<sub>2</sub>O -> H<sup>+</sup> + OH<sup>-</sup><br>Fe(NH<sub>4</sub>)<sub>2</sub>(SO<sub>4</sub>)<sub>2</sub> <sup>.</sup> 6H<sub>2</sub>O -> Fe<sup>2+</sup> + 2NH<sub>4</sub><sup>+</sup> + 2SO<sub>4</sub><sup>2-</sup><br>16H<sup>+</sup> + 2MnO4- + 5C2O42- -> 2Mn<sup>2+</sup> + 8H<sub>2</sub>O + 10CO2

# %%
#
